# %%
#Typecasting

# %%
#int typecasting

# %%
#int to float

# %%
5
# Out:
# 5

# %%
float(5)
# Out:
# 5.0

# %%
_+6
# Out:
# 11.0

# %%
v = 8
float(v)
# Out:
# 8.0

# %%
#int to boolean

# %%
bool(5)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(-7)
# Out:
# True

# %%
#int to bool

# %%
complex(3)
# Out:
# (3+0j)

# %%
complex(3,4)
# Out:
# (3+4j)

# %%
complex(1000)
# Out:
# (1000+0j)

# %%
#int to string

# %%
str(1)
# Out:
# '1'

# %%
str(298)
# Out:
# '298'

# %%
#float typecasting

# %%
#float to int

# %%
int(5.55)
# Out:
# 5

# %%
int(5.95)
# Out:
# 5

# %%
int(5.6)
# Out:
# 5

# %%
int(6.1)
# Out:
# 6

# %%
int(5.99)
# Out:
# 5

# %%
v = 5.6
s = 6.4

# %%
print(int(v)+int(s))
# Out:
# 11

# %%
l = int(v)
print(v+l)
# Out:
# 10.6

# %%
#float to string

# %%
str(6.7)
# Out:
# '6.7'

# %%
str(35.67)
# Out:
# '35.67'

# %%
#float to boolean

# %%
bool(9.67)
# Out:
# True

# %%
#float to complex

# %%
complex(4.7)
# Out:
# (4.7+0j)

# %%
complex(9.0)
# Out:
# (9+0j)

# %%
complex(2.3,4.6)
# Out:
# (2.3+4.6j)
