# %%
i=5
type(i)
# Out:
# int

# %%
p = 107.6
type(p)
# Out:
# float

# %%
3e0
# Out:
# 3.0

# %%
5e2
# Out:
# 500.0

# %%
7e3
# Out:
# 7000.0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
t=True
f=False
s=t+f
print(t+f)
print(t-f)
print(t*f)
print(f/t)
print(f//t)
print(s)
# Out:
# 1
# 1
# 0
# 0.0
# 0
# 1

# %%
c = 10 + 5j
c
# Out:
# (10+5j)

# %%
t=True
f=False
s=t+f
print(s)
# Out:
# 1

# %%
type(t)
# Out:
# bool

# %%
type(s)
# Out:
# int

# %%
c = 10 + 5j
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 5.0

# %%
h = c.real/c.imag
print(h)
# Out:
# 2.0

# %%
type(h)
# Out:
# float

# %%
f = 35 + 45j
type(f)
# Out:
# complex

# %%
j = f.real
# Out:
# 35.0

# %%
l = f.imag
# Out:
# 45.0

# %%
c = 10 + 5j
f = 35 + 45j
u = c+f
print(u)
# Out:
# (45+50j)
