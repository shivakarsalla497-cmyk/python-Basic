# %%
#sring
'welcome'
# Out:
# 'welcome'

# %%
v ='auto'
b ='car'

# %%
print(v,b)
# Out:
# auto car

# %%
len(v)
# Out:
# 4

# %%
id(v)
# Out:
# 2516607882688

# %%
type(b)
# Out:
# str

# %%
v[2]
# Out:
# 't'

# %%
b[0]
# Out:
# 'c'

# %%
k = 'shivakar'
k
# Out:
# 'shivakar'

# %%
print(k[0])
print(k[1])
print(k[2])
# Out:
# s
# h
# i

# %%
k[5]
# Out:
# 'k'

# %%
k[6]
# Out:
# 'a'

# %%
k[7]
# Out:
# 'r'

# %%
m = 'shivakar'
m
# Out:
# 'shivakar'

# %%
m[0:6]
# Out:
# 'shivak'

# %%
m[2:4]
# Out:
# 'iv'

# %%
m[2:5]
# Out:
# 'iva'

# %%
m[5:8]
# Out:
# 'kar'

# %%
m[4:7]
# Out:
# 'aka'

# %%
m[3:7]
# Out:
# 'vaka'

# %%
m[2:7]
# Out:
# 'ivaka'

# %%
m[1:5]
# Out:
# 'hiva'

# %%
f = "HOUSE"
f
# Out:
# 'HOUSE'

# %%
f[1:4]
# Out:
# 'OUS'

# %%
f[4]
# Out:
# 'E'

# %%
f[0:3]
# Out:
# 'HOU'

# %%
f[1:100]
# Out:
# 'OUSE'

# %%
f[3:1000]
# Out:
# 'SE'

# %%
d = "Wonderfull"
d
# Out:
# 'Wonderfull'

# %%
d[4]
# Out:
# 'e'

# %%
d[3:7]
# Out:
# 'derf'

# %%
d[3:]
# Out:
# 'derfull'

# %%
d[:3]
# Out:
# 'Won'

# %%
d[:9]
# Out:
# 'Wonderful'

# %%
d[:7]
# Out:
# 'Wonderf'

# %%
d
# Out:
# 'Wonderfull'

# %%
d[-1]
# Out:
# 'l'

# %%
d[-10]
# Out:
# 'W'

# %%
d[-8:-3]
# Out:
# 'nderf'

# %%
d[-7:-2]
# Out:
# 'derfu'

# %%
print(d[-9:-4])
print(d[-6:1000])
# Out:
# onder
# erfull
